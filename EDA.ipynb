# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load dataset (replace file path if needed)
df = pd.read_csv("movie_metadata.csv")

# Display first 5 rows
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0              33000.0
# 1                  0.0
# 2              85000.0
# 3             164000.0
# 4                  0.0
#
# [5 rows x 28 columns]

# %%
# Dataset info
df.info()

# Statistical summary
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3477 entries, 0 to 3476
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      3469 non-null   object
#  1   director_name              3412 non-null   object
#  2   num_critic_for_reviews     3466 non-null   float64
#  3   duration                   3472 non-null   float64
#  4   director_facebook_likes    3411 non-null   float64
#  5   actor_3_facebook_likes     3470 non-null   float64
#  6   actor_2_name               3472 non-null   object
#  7   actor_1_facebook_likes     3476 non-null   float64
#  8   gross                      3179 non-null   float64
#  9   genres                     3476 non-null   object
#  10  actor_1_name               3476 non-null   object
#  11  movie_title                3476 non-null   object
#  12  num_voted_users            3476 non-null   float64
#  13  cast_total_facebook_likes  3476 non-null   float64
#  14  actor_3_name               3470 non-null   object
#  15  facenumber_in_poster       3471 non-null   float64
#  16  plot_keywords              3432 non-null   object
#  17  movie_imdb_link            3476 non-null   object
#  18  num_user_for_reviews       3468 non-null   float64
#  19  language                   3471 non-null   object
#  20  country                    3472 non-null   object
#  21  content_rating             3393 non-null   object
#  22  budget                     3249 non-null   float64
#  23  title_year                 3407 non-null   float64
#  24  actor_2_facebook_likes     3472 non-null   float64
#  25  imdb_score                 3476 non-null   float64
#  26  aspect_ratio               3399 non-null   float64
#  27  movie_facebook_likes       3476 non-null   float64
# dtypes: float64(16), object(12)
# memory usage: 760.7+ KB
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             3466.000000  3472.000000              3411.000000
# mean               162.487882   110.925403               822.595427
# std                124.876849    26.326144              3091.005658
# min                  1.000000     7.000000                 0.000000
# 25%                 72.000000    96.000000                11.000000
# 50%                133.000000   107.000000                65.000000
# 75%                220.000000   122.000000               249.000000
# max                813.000000   511.000000             22000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             3470.000000             3476.000000  3.179000e+03
# mean               806.651297             7929.611910  5.924288e+07
# std               1948.988667            15286.469725  7.302573e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                213.000000              787.000000  1.374855e+07
# 50%                460.000000             2000.000000  3.603791e+07
# 75%                716.000000            13000.000000  7.545080e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     3.476000e+03                3476.000000           3471.000000
# mean      1.057553e+05               11877.039701              1.425238
# std       1.539312e+05               19045.776442              2.082613
# min       6.000000e+00                   0.000000              0.000000
# 25%       1.869600e+04                2042.000000              0.000000
# 50%       5.329600e+04                4349.500000              1.000000
# 75%       1.283432e+05               16692.250000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           3468.000000  3.249000e+03  3407.000000
# mean             329.561707  5.158639e+07  2003.613736
# std              413.505194  2.302896e+08     9.324855
# min                1.000000  1.300000e+04  1927.000000
# 25%              102.000000  1.600000e+07  1999.000000
# 50%              202.000000  3.000000e+07  2005.000000
# 75%              392.000000  5.800000e+07  2010.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             3472.000000  3476.000000   3399.000000           3476.000000
# mean              2118.673675     6.423331      2.225216           9331.742520
# std               4646.642262     1.072988      1.144905          21917.863983
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                416.000000     5.800000      1.850000              0.000000
# 50%                718.000000     6.500000      2.350000            207.000000
# 75%                989.000000     7.200000      2.350000          11000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %%
# Check missing values
df.isnull().sum()

# Fill missing values with mean (for numeric columns)
df.fillna(df.mean(numeric_only=True), inplace=True)

# Verify again
df.isnull().sum()
# Out:
# color                         8
# director_name                65
# num_critic_for_reviews        0
# duration                      0
# director_facebook_likes       0
# actor_3_facebook_likes        0
# actor_2_name                  5
# actor_1_facebook_likes        0
# gross                         0
# genres                        1
# actor_1_name                  1
# movie_title                   1
# num_voted_users               0
# cast_total_facebook_likes     0
# actor_3_name                  7
# facenumber_in_poster          0
# plot_keywords                45
# movie_imdb_link               1
# num_user_for_reviews          0
# language                      6
# country                       5
# content_rating               84
# budget                        0
# title_year                    0
# actor_2_facebook_likes        0
# imdb_score                    0
# aspect_ratio                  0
# movie_facebook_likes          0
# dtype: int64

# %%
# Mean
print("Mean:\n", df.mean(numeric_only=True))
# Out:
# Mean:
#  num_critic_for_reviews       1.624879e+02
# duration                     1.109254e+02
# director_facebook_likes      8.225954e+02
# actor_3_facebook_likes       8.066513e+02
# actor_1_facebook_likes       7.929612e+03
# gross                        5.924288e+07
# num_voted_users              1.057553e+05
# cast_total_facebook_likes    1.187704e+04
# facenumber_in_poster         1.425238e+00
# num_user_for_reviews         3.295617e+02
# budget                       5.158639e+07
# title_year                   2.003614e+03
# actor_2_facebook_likes       2.118674e+03
# imdb_score                   6.423331e+00
# aspect_ratio                 2.225216e+00
# movie_facebook_likes         9.331743e+03
# dtype: float64

# %%
# Minimum
print("Minimum:\n", df.min(numeric_only=True))
# Out:
# Minimum:
#  num_critic_for_reviews           1.00
# duration                         7.00
# director_facebook_likes          0.00
# actor_3_facebook_likes           0.00
# actor_1_facebook_likes           0.00
# gross                          162.00
# num_voted_users                  6.00
# cast_total_facebook_likes        0.00
# facenumber_in_poster             0.00
# num_user_for_reviews             1.00
# budget                       13000.00
# title_year                    1927.00
# actor_2_facebook_likes           0.00
# imdb_score                       1.60
# aspect_ratio                     1.18
# movie_facebook_likes             0.00
# dtype: float64

# %%
# Maximum
print("Maximum:\n", df.max(numeric_only=True))
# Out:
# Maximum:
#  num_critic_for_reviews       8.130000e+02
# duration                     5.110000e+02
# director_facebook_likes      2.200000e+04
# actor_3_facebook_likes       2.300000e+04
# actor_1_facebook_likes       6.400000e+05
# gross                        7.605058e+08
# num_voted_users              1.689764e+06
# cast_total_facebook_likes    6.567300e+05
# facenumber_in_poster         4.300000e+01
# num_user_for_reviews         5.060000e+03
# budget                       1.221550e+10
# title_year                   2.016000e+03
# actor_2_facebook_likes       1.370000e+05
# imdb_score                   9.500000e+00
# aspect_ratio                 1.600000e+01
# movie_facebook_likes         3.490000e+05
# dtype: float64

# %%
# Plot histogram
df.hist(figsize=(10,8))
plt.show()

# %%
# Boxplot for all numeric columns
df.plot(kind='box', figsize=(10,6))
plt.show()

# %%
# Replace 'column_name' with actual column
df['column_name'].hist()
plt.title("Histogram")
plt.show()

df.boxplot(column='column_name')
plt.show()
