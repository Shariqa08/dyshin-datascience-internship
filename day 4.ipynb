# %%
# Creating a dictionary

student = {
    "name": "Shariqa",
    "age": 21,
    "course": "Data Science"
}

print("Student Dictionary:", student)
# Out:
# Student Dictionary: {'name': 'Shariqa', 'age': 21, 'course': 'Data Science'}

# %%
# Accessing values using keys

print("Student Name:", student["name"])
print("Course:", student["course"])
# Out:
# Student Name: Shariqa
# Course: Data Science

# %%
# Adding new data to dictionary

student["city"] = "Bangalore"

print("Updated Dictionary:", student)
# Out:
# Updated Dictionary: {'name': 'Shariqa', 'age': 21, 'course': 'Data Science', 'city': 'Bangalore'}

# %%
# Updating existing value

student["age"] = 22

print("Dictionary after update:", student)
# Out:
# Dictionary after update: {'name': 'Shariqa', 'age': 22, 'course': 'Data Science', 'city': 'Bangalore'}

# %%
# Dictionary methods

print("Keys:", student.keys())
print("Values:", student.values())
print("Items:", student.items())
# Out:
# Keys: dict_keys(['name', 'age', 'course', 'city'])
# Values: dict_values(['Shariqa', 22, 'Data Science', 'Bangalore'])
# Items: dict_items([('name', 'Shariqa'), ('age', 22), ('course', 'Data Science'), ('city', 'Bangalore')])

# %%
# Removing an element

student.pop("city")

print("Dictionary after removing city:", student)
# Out:
# Dictionary after removing city: {'name': 'Shariqa', 'age': 22, 'course': 'Data Science'}

# %%
# Storing marks of subjects

marks = {
    "Math": 85,
    "Science": 90,
    "English": 88
}

# Calculate total marks
total = sum(marks.values())

print("Marks:", marks)
print("Total Marks:", total)
# Out:
# Marks: {'Math': 85, 'Science': 90, 'English': 88}
# Total Marks: 263
